# %%
# ATTENTION: Please do not alter any of the provided code in the exercise. Only add your own code where indicated
# ATTENTION: Please do not add or remove any cells in the exercise. The grader will check specific cells based on the cell position.
# ATTENTION: Please use the provided epoch values when training.

# In this exercise you will train a CNN on the FULL Cats-v-dogs dataset
# This will require you doing a lot of data preprocessing because
# the dataset isn't split into training and validation for you
# This code block has all the required inputs
import os
import zipfile
import random
import tensorflow as tf
import shutil
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
from os import getcwd

# %%
path_cats_and_dogs = f"{getcwd()}/../tmp2/cats-and-dogs.zip"
shutil.rmtree('/tmp')

local_zip = path_cats_and_dogs
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
print(len(os.listdir('/tmp/PetImages/Cat/')))
print(len(os.listdir('/tmp/PetImages/Dog/')))

# Expected Output:
# 1500
# 1500
# Out:
# 1500
# 1500

# %%
# Use os.mkdir to create your directories
# You will need a directory for cats-v-dogs, and subdirectories for training
# and testing. These in turn will need subdirectories for 'cats' and 'dogs'
try:
    #YOUR CODE GOES HERE
    os.mkdir("/tmp/cats-v-dogs/")
    os.mkdir('/tmp/cats-v-dogs/training')
    os.mkdir('/tmp/cats-v-dogs/testing')
    os.mkdir("/tmp/cats-v-dogs/training/cats/")
    os.mkdir("/tmp/cats-v-dogs/training/dogs/")
    os.mkdir("/tmp/cats-v-dogs/testing/cats/")
    os.mkdir("/tmp/cats-v-dogs/testing/dogs/")
except OSError:
    pass

# %%
# Write a python function called split_data which takes
# a SOURCE directory containing the files
# a TRAINING directory that a portion of the files will be copied to
# a TESTING directory that a portion of the files will be copie to
# a SPLIT SIZE to determine the portion
# The files should also be randomized, so that the training set is a random
# X% of the files, and the test set is the remaining files
# SO, for example, if SOURCE is PetImages/Cat, and SPLIT SIZE is .9
# Then 90% of the images in PetImages/Cat will be copied to the TRAINING dir
# and 10% of the images will be copied to the TESTING dir
# Also -- All images should be checked, and if they have a zero file length,
# they will not be copied over
#
# os.listdir(DIRECTORY) gives you a listing of the contents of that directory
# os.path.getsize(PATH) gives you the size of the file
# copyfile(source, destination) copies a file from source to destination
# random.sample(list, len(list)) shuffles a list
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
# YOUR CODE STARTS HERE
    item_list = os.listdir(SOURCE)
    item_count = len(item_list)
    training_size = int(item_count * SPLIT_SIZE)
    training = random.sample(item_list, training_size)
    testing = list()
    for i in training:
        source_path = os.path.join(SOURCE,i)
        destination_path = os.path.join(TRAINING,i)
        if os.path.getsize(source_path) == 0:
            continue
        copyfile(source_path, destination_path)
        
    for i in item_list:
        if i not in training:
            source_path = os.path.join(SOURCE,i)
            destination_path = os.path.join(TESTING,i)
            if os.path.getsize(source_path) == 0:
                continue
            testing.append(i)
            copyfile(source_path, destination_path)
# YOUR CODE ENDS HERE


CAT_SOURCE_DIR = "/tmp/PetImages/Cat/"
TRAINING_CATS_DIR = "/tmp/cats-v-dogs/training/cats/"
TESTING_CATS_DIR = "/tmp/cats-v-dogs/testing/cats/"
DOG_SOURCE_DIR = "/tmp/PetImages/Dog/"
TRAINING_DOGS_DIR = "/tmp/cats-v-dogs/training/dogs/"
TESTING_DOGS_DIR = "/tmp/cats-v-dogs/testing/dogs/"

split_size = .9
split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)
# Out:
# TESTING /tmp/cats-v-dogs/testing/cats/
# TRAINING /tmp/cats-v-dogs/training/cats/
# source_path /tmp/PetImages/Cat/cat.887.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.887.jpg
# source_path /tmp/PetImages/Cat/cat.618.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.618.jpg
# source_path /tmp/PetImages/Cat/cat.821.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.821.jpg
# source_path /tmp/PetImages/Cat/cat.42.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.42.jpg
# source_path /tmp/PetImages/Cat/cat.2401.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2401.jpg
# source_path /tmp/PetImages/Cat/cat.289.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.289.jpg
# source_path /tmp/PetImages/Cat/cat.2377.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2377.jpg
# source_path /tmp/PetImages/Cat/cat.719.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.719.jpg
# source_path /tmp/PetImages/Cat/cat.767.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.767.jpg
# source_path /tmp/PetImages/Cat/cat.453.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.453.jpg
# source_path /tmp/PetImages/Cat/cat.569.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.569.jpg
# source_path /tmp/PetImages/Cat/cat.55.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.55.jpg
# source_path /tmp/PetImages/Cat/cat.2324.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2324.jpg
# source_path /tmp/PetImages/Cat/cat.2088.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2088.jpg
# source_path /tmp/PetImages/Cat/cat.184.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.184.jpg
# source_path /tmp/PetImages/Cat/cat.831.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.831.jpg
# source_path /tmp/PetImages/Cat/cat.308.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.308.jpg
# source_path /tmp/PetImages/Cat/cat.2322.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2322.jpg
# source_path /tmp/PetImages/Cat/cat.901.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.901.jpg
# source_path /tmp/PetImages/Cat/cat.2359.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2359.jpg
# source_path /tmp/PetImages/Cat/cat.2240.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2240.jpg
# source_path /tmp/PetImages/Cat/cat.594.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.594.jpg
# source_path /tmp/PetImages/Cat/cat.2233.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2233.jpg
# source_path /tmp/PetImages/Cat/cat.852.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.852.jpg
# source_path /tmp/PetImages/Cat/cat.225.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.225.jpg
# source_path /tmp/PetImages/Cat/cat.2037.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2037.jpg
# source_path /tmp/PetImages/Cat/cat.223.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.223.jpg
# source_path /tmp/PetImages/Cat/cat.2139.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2139.jpg
# source_path /tmp/PetImages/Cat/cat.627.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.627.jpg
# source_path /tmp/PetImages/Cat/cat.369.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.369.jpg
# source_path /tmp/PetImages/Cat/cat.497.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.497.jpg
# source_path /tmp/PetImages/Cat/cat.551.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.551.jpg
# source_path /tmp/PetImages/Cat/cat.2053.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2053.jpg
# source_path /tmp/PetImages/Cat/cat.2095.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2095.jpg
# source_path /tmp/PetImages/Cat/cat.992.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.992.jpg
# source_path /tmp/PetImages/Cat/cat.182.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.182.jpg
# source_path /tmp/PetImages/Cat/cat.2284.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2284.jpg
# source_path /tmp/PetImages/Cat/cat.796.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.796.jpg
# source_path /tmp/PetImages/Cat/cat.2341.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2341.jpg
# source_path /tmp/PetImages/Cat/cat.863.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.863.jpg
# source_path /tmp/PetImages/Cat/cat.896.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.896.jpg
# source_path /tmp/PetImages/Cat/cat.95.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.95.jpg
# source_path /tmp/PetImages/Cat/cat.424.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.424.jpg
# source_path /tmp/PetImages/Cat/cat.2491.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2491.jpg
# source_path /tmp/PetImages/Cat/cat.300.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.300.jpg
# source_path /tmp/PetImages/Cat/cat.2030.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2030.jpg
# source_path /tmp/PetImages/Cat/cat.775.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.775.jpg
# source_path /tmp/PetImages/Cat/cat.2167.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2167.jpg
# source_path /tmp/PetImages/Cat/cat.2133.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2133.jpg
# source_path /tmp/PetImages/Cat/cat.939.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.939.jpg
# source_path /tmp/PetImages/Cat/cat.381.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.381.jpg
# source_path /tmp/PetImages/Cat/cat.2348.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2348.jpg
# source_path /tmp/PetImages/Cat/cat.151.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.151.jpg
# source_path /tmp/PetImages/Cat/cat.2483.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2483.jpg
# source_path /tmp/PetImages/Cat/cat.452.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.452.jpg
# source_path /tmp/PetImages/Cat/cat.583.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.583.jpg
# source_path /tmp/PetImages/Cat/cat.2498.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2498.jpg
# source_path /tmp/PetImages/Cat/cat.386.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.386.jpg
# source_path /tmp/PetImages/Cat/cat.2200.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2200.jpg
# source_path /tmp/PetImages/Cat/cat.2318.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2318.jpg
# source_path /tmp/PetImages/Cat/cat.851.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.851.jpg
# source_path /tmp/PetImages/Cat/cat.385.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.385.jpg
# source_path /tmp/PetImages/Cat/cat.2084.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2084.jpg
# source_path /tmp/PetImages/Cat/cat.114.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.114.jpg
# source_path /tmp/PetImages/Cat/cat.206.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.206.jpg
# source_path /tmp/PetImages/Cat/cat.2440.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2440.jpg
# source_path /tmp/PetImages/Cat/cat.868.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.868.jpg
# source_path /tmp/PetImages/Cat/cat.2238.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2238.jpg
# source_path /tmp/PetImages/Cat/cat.97.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.97.jpg
# source_path /tmp/PetImages/Cat/cat.624.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.624.jpg
# source_path /tmp/PetImages/Cat/cat.2184.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2184.jpg
# source_path /tmp/PetImages/Cat/cat.2197.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2197.jpg
# source_path /tmp/PetImages/Cat/cat.2312.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2312.jpg
# source_path /tmp/PetImages/Cat/cat.2393.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2393.jpg
# source_path /tmp/PetImages/Cat/cat.752.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.752.jpg
# source_path /tmp/PetImages/Cat/cat.814.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.814.jpg
# source_path /tmp/PetImages/Cat/cat.546.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.546.jpg
# source_path /tmp/PetImages/Cat/cat.2099.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2099.jpg
# source_path /tmp/PetImages/Cat/cat.2153.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2153.jpg
# source_path /tmp/PetImages/Cat/cat.3.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.3.jpg
# source_path /tmp/PetImages/Cat/cat.2244.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2244.jpg
# source_path /tmp/PetImages/Cat/cat.2292.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2292.jpg
# source_path /tmp/PetImages/Cat/cat.602.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.602.jpg
# source_path /tmp/PetImages/Cat/cat.2176.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2176.jpg
# source_path /tmp/PetImages/Cat/cat.2068.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2068.jpg
# source_path /tmp/PetImages/Cat/cat.2364.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2364.jpg
# source_path /tmp/PetImages/Cat/cat.2361.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2361.jpg
# source_path /tmp/PetImages/Cat/cat.2130.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2130.jpg
# source_path /tmp/PetImages/Cat/cat.327.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.327.jpg
# source_path /tmp/PetImages/Cat/cat.2317.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2317.jpg
# source_path /tmp/PetImages/Cat/cat.82.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.82.jpg
# source_path /tmp/PetImages/Cat/cat.2202.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2202.jpg
# source_path /tmp/PetImages/Cat/cat.175.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.175.jpg
# source_path /tmp/PetImages/Cat/cat.410.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.410.jpg
# source_path /tmp/PetImages/Cat/cat.909.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.909.jpg
# source_path /tmp/PetImages/Cat/cat.92.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.92.jpg
# source_path /tmp/PetImages/Cat/cat.761.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.761.jpg
# source_path /tmp/PetImages/Cat/cat.2278.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2278.jpg
# source_path /tmp/PetImages/Cat/cat.558.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.558.jpg
# source_path /tmp/PetImages/Cat/cat.422.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.422.jpg
# source_path /tmp/PetImages/Cat/cat.382.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.382.jpg
# source_path /tmp/PetImages/Cat/cat.283.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.283.jpg
# source_path /tmp/PetImages/Cat/cat.2272.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2272.jpg
# source_path /tmp/PetImages/Cat/cat.459.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.459.jpg
# source_path /tmp/PetImages/Cat/cat.860.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.860.jpg
# source_path /tmp/PetImages/Cat/cat.2346.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2346.jpg
# source_path /tmp/PetImages/Cat/cat.876.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.876.jpg
# source_path /tmp/PetImages/Cat/cat.355.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.355.jpg
# source_path /tmp/PetImages/Cat/cat.392.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.392.jpg
# source_path /tmp/PetImages/Cat/cat.517.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.517.jpg
# source_path /tmp/PetImages/Cat/cat.981.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.981.jpg
# source_path /tmp/PetImages/Cat/cat.2221.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2221.jpg
# source_path /tmp/PetImages/Cat/cat.966.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.966.jpg
# source_path /tmp/PetImages/Cat/cat.416.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.416.jpg
# source_path /tmp/PetImages/Cat/cat.467.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.467.jpg
# source_path /tmp/PetImages/Cat/cat.705.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.705.jpg
# source_path /tmp/PetImages/Cat/cat.622.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.622.jpg
# source_path /tmp/PetImages/Cat/cat.142.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.142.jpg
# source_path /tmp/PetImages/Cat/cat.2250.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2250.jpg
# source_path /tmp/PetImages/Cat/cat.2178.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2178.jpg
# source_path /tmp/PetImages/Cat/cat.66.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.66.jpg
# source_path /tmp/PetImages/Cat/cat.106.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.106.jpg
# source_path /tmp/PetImages/Cat/cat.597.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.597.jpg
# source_path /tmp/PetImages/Cat/cat.197.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.197.jpg
# source_path /tmp/PetImages/Cat/cat.894.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.894.jpg
# source_path /tmp/PetImages/Cat/cat.307.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.307.jpg
# source_path /tmp/PetImages/Cat/cat.26.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.26.jpg
# source_path /tmp/PetImages/Cat/cat.254.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.254.jpg
# source_path /tmp/PetImages/Cat/cat.250.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.250.jpg
# source_path /tmp/PetImages/Cat/cat.2333.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2333.jpg
# source_path /tmp/PetImages/Cat/cat.2489.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2489.jpg
# source_path /tmp/PetImages/Cat/cat.672.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.672.jpg
# source_path /tmp/PetImages/Cat/cat.391.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.391.jpg
# source_path /tmp/PetImages/Cat/cat.2196.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2196.jpg
# source_path /tmp/PetImages/Cat/cat.431.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.431.jpg
# source_path /tmp/PetImages/Cat/cat.2050.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2050.jpg
# source_path /tmp/PetImages/Cat/cat.2002.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2002.jpg
# source_path /tmp/PetImages/Cat/cat.378.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.378.jpg
# source_path /tmp/PetImages/Cat/cat.2365.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2365.jpg
# source_path /tmp/PetImages/Cat/cat.937.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.937.jpg
# source_path /tmp/PetImages/Cat/cat.990.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.990.jpg
# source_path /tmp/PetImages/Cat/cat.470.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.470.jpg
# source_path /tmp/PetImages/Cat/cat.484.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.484.jpg
# source_path /tmp/PetImages/Cat/cat.717.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.717.jpg
# source_path /tmp/PetImages/Cat/cat.2161.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2161.jpg
# source_path /tmp/PetImages/Cat/cat.311.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.311.jpg
# source_path /tmp/PetImages/Cat/cat.2234.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2234.jpg
# source_path /tmp/PetImages/Cat/cat.372.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.372.jpg
# source_path /tmp/PetImages/Cat/cat.6.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.6.jpg
# source_path /tmp/PetImages/Cat/cat.402.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.402.jpg
# source_path /tmp/PetImages/Cat/cat.690.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.690.jpg
# source_path /tmp/PetImages/Cat/cat.2374.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2374.jpg
# source_path /tmp/PetImages/Cat/cat.942.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.942.jpg
# source_path /tmp/PetImages/Cat/cat.669.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.669.jpg
# source_path /tmp/PetImages/Cat/cat.898.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.898.jpg
# source_path /tmp/PetImages/Cat/cat.2352.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2352.jpg
# source_path /tmp/PetImages/Cat/cat.2142.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2142.jpg
# source_path /tmp/PetImages/Cat/cat.265.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.265.jpg
# source_path /tmp/PetImages/Cat/cat.870.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.870.jpg
# source_path /tmp/PetImages/Cat/cat.279.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.279.jpg
# source_path /tmp/PetImages/Cat/cat.506.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.506.jpg
# source_path /tmp/PetImages/Cat/cat.2020.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2020.jpg
# source_path /tmp/PetImages/Cat/cat.542.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.542.jpg
# source_path /tmp/PetImages/Cat/cat.75.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.75.jpg
# source_path /tmp/PetImages/Cat/cat.162.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.162.jpg
# source_path /tmp/PetImages/Cat/cat.18.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.18.jpg
# source_path /tmp/PetImages/Cat/cat.2289.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2289.jpg
# source_path /tmp/PetImages/Cat/cat.276.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.276.jpg
# source_path /tmp/PetImages/Cat/cat.890.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.890.jpg
# source_path /tmp/PetImages/Cat/cat.360.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.360.jpg
# source_path /tmp/PetImages/Cat/cat.614.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.614.jpg
# source_path /tmp/PetImages/Cat/cat.963.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.963.jpg
# source_path /tmp/PetImages/Cat/cat.132.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.132.jpg
# source_path /tmp/PetImages/Cat/cat.361.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.361.jpg
# source_path /tmp/PetImages/Cat/cat.559.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.559.jpg
# source_path /tmp/PetImages/Cat/cat.2226.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2226.jpg
# source_path /tmp/PetImages/Cat/cat.310.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.310.jpg
# source_path /tmp/PetImages/Cat/cat.340.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.340.jpg
# source_path /tmp/PetImages/Cat/cat.579.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.579.jpg
# source_path /tmp/PetImages/Cat/cat.2399.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2399.jpg
# source_path /tmp/PetImages/Cat/cat.662.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.662.jpg
# source_path /tmp/PetImages/Cat/cat.160.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.160.jpg
# source_path /tmp/PetImages/Cat/cat.2319.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2319.jpg
# source_path /tmp/PetImages/Cat/cat.590.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.590.jpg
# source_path /tmp/PetImages/Cat/cat.2303.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2303.jpg
# source_path /tmp/PetImages/Cat/cat.2276.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2276.jpg
# source_path /tmp/PetImages/Cat/cat.47.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.47.jpg
# source_path /tmp/PetImages/Cat/cat.111.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.111.jpg
# source_path /tmp/PetImages/Cat/cat.2048.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2048.jpg
# source_path /tmp/PetImages/Cat/cat.2499.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2499.jpg
# source_path /tmp/PetImages/Cat/cat.2006.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2006.jpg
# source_path /tmp/PetImages/Cat/cat.545.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.545.jpg
# source_path /tmp/PetImages/Cat/cat.2254.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2254.jpg
# source_path /tmp/PetImages/Cat/cat.331.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.331.jpg
# source_path /tmp/PetImages/Cat/cat.754.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.754.jpg
# source_path /tmp/PetImages/Cat/cat.751.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.751.jpg
# source_path /tmp/PetImages/Cat/cat.557.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.557.jpg
# source_path /tmp/PetImages/Cat/cat.664.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.664.jpg
# source_path /tmp/PetImages/Cat/cat.2442.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2442.jpg
# source_path /tmp/PetImages/Cat/cat.905.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.905.jpg
# source_path /tmp/PetImages/Cat/cat.0.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.0.jpg
# source_path /tmp/PetImages/Cat/cat.2165.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2165.jpg
# source_path /tmp/PetImages/Cat/cat.56.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.56.jpg
# source_path /tmp/PetImages/Cat/cat.2194.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2194.jpg
# source_path /tmp/PetImages/Cat/cat.2280.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2280.jpg
# source_path /tmp/PetImages/Cat/cat.269.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.269.jpg
# source_path /tmp/PetImages/Cat/cat.304.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.304.jpg
# source_path /tmp/PetImages/Cat/cat.543.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.543.jpg
# source_path /tmp/PetImages/Cat/cat.436.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.436.jpg
# source_path /tmp/PetImages/Cat/cat.572.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.572.jpg
# source_path /tmp/PetImages/Cat/cat.501.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.501.jpg
# source_path /tmp/PetImages/Cat/cat.272.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.272.jpg
# source_path /tmp/PetImages/Cat/cat.2487.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2487.jpg
# source_path /tmp/PetImages/Cat/cat.698.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.698.jpg
# source_path /tmp/PetImages/Cat/cat.100.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.100.jpg
# source_path /tmp/PetImages/Cat/cat.395.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.395.jpg
# source_path /tmp/PetImages/Cat/cat.2019.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2019.jpg
# source_path /tmp/PetImages/Cat/cat.2330.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2330.jpg
# source_path /tmp/PetImages/Cat/cat.910.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.910.jpg
# source_path /tmp/PetImages/Cat/cat.2123.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2123.jpg
# source_path /tmp/PetImages/Cat/cat.2290.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2290.jpg
# source_path /tmp/PetImages/Cat/cat.465.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.465.jpg
# source_path /tmp/PetImages/Cat/cat.812.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.812.jpg
# source_path /tmp/PetImages/Cat/cat.2207.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2207.jpg
# source_path /tmp/PetImages/Cat/cat.290.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.290.jpg
# source_path /tmp/PetImages/Cat/cat.766.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.766.jpg
# source_path /tmp/PetImages/Cat/cat.368.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.368.jpg
# source_path /tmp/PetImages/Cat/cat.2223.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2223.jpg
# source_path /tmp/PetImages/Cat/cat.267.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.267.jpg
# source_path /tmp/PetImages/Cat/cat.2433.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2433.jpg
# source_path /tmp/PetImages/Cat/cat.2158.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2158.jpg
# source_path /tmp/PetImages/Cat/cat.429.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.429.jpg
# source_path /tmp/PetImages/Cat/cat.224.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.224.jpg
# source_path /tmp/PetImages/Cat/cat.2424.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2424.jpg
# source_path /tmp/PetImages/Cat/cat.2137.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2137.jpg
# source_path /tmp/PetImages/Cat/cat.2125.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2125.jpg
# source_path /tmp/PetImages/Cat/cat.2426.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2426.jpg
# source_path /tmp/PetImages/Cat/cat.63.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.63.jpg
# source_path /tmp/PetImages/Cat/cat.65.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.65.jpg
# source_path /tmp/PetImages/Cat/cat.741.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.741.jpg
# source_path /tmp/PetImages/Cat/cat.362.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.362.jpg
# source_path /tmp/PetImages/Cat/cat.227.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.227.jpg
# source_path /tmp/PetImages/Cat/cat.565.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.565.jpg
# source_path /tmp/PetImages/Cat/cat.866.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.866.jpg
# source_path /tmp/PetImages/Cat/cat.103.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.103.jpg
# source_path /tmp/PetImages/Cat/cat.530.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.530.jpg
# source_path /tmp/PetImages/Cat/cat.2258.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2258.jpg
# source_path /tmp/PetImages/Cat/cat.803.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.803.jpg
# source_path /tmp/PetImages/Cat/cat.2281.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2281.jpg
# source_path /tmp/PetImages/Cat/cat.456.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.456.jpg
# source_path /tmp/PetImages/Cat/cat.2041.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2041.jpg
# source_path /tmp/PetImages/Cat/cat.949.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.949.jpg
# source_path /tmp/PetImages/Cat/cat.185.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.185.jpg
# source_path /tmp/PetImages/Cat/cat.998.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.998.jpg
# source_path /tmp/PetImages/Cat/cat.180.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.180.jpg
# source_path /tmp/PetImages/Cat/cat.686.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.686.jpg
# source_path /tmp/PetImages/Cat/cat.2453.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2453.jpg
# source_path /tmp/PetImages/Cat/cat.260.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.260.jpg
# source_path /tmp/PetImages/Cat/cat.44.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.44.jpg
# source_path /tmp/PetImages/Cat/cat.2032.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2032.jpg
# source_path /tmp/PetImages/Cat/cat.248.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.248.jpg
# source_path /tmp/PetImages/Cat/cat.177.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.177.jpg
# source_path /tmp/PetImages/Cat/cat.679.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.679.jpg
# source_path /tmp/PetImages/Cat/cat.2462.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2462.jpg
# source_path /tmp/PetImages/Cat/cat.165.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.165.jpg
# source_path /tmp/PetImages/Cat/cat.2463.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2463.jpg
# source_path /tmp/PetImages/Cat/cat.599.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.599.jpg
# source_path /tmp/PetImages/Cat/cat.656.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.656.jpg
# source_path /tmp/PetImages/Cat/cat.2400.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2400.jpg
# source_path /tmp/PetImages/Cat/cat.2397.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2397.jpg
# source_path /tmp/PetImages/Cat/cat.7.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.7.jpg
# source_path /tmp/PetImages/Cat/cat.2104.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2104.jpg
# source_path /tmp/PetImages/Cat/cat.79.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.79.jpg
# source_path /tmp/PetImages/Cat/cat.839.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.839.jpg
# source_path /tmp/PetImages/Cat/cat.2444.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2444.jpg
# source_path /tmp/PetImages/Cat/cat.986.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.986.jpg
# source_path /tmp/PetImages/Cat/cat.2308.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2308.jpg
# source_path /tmp/PetImages/Cat/cat.38.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.38.jpg
# source_path /tmp/PetImages/Cat/cat.563.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.563.jpg
# source_path /tmp/PetImages/Cat/cat.696.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.696.jpg
# source_path /tmp/PetImages/Cat/cat.2009.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2009.jpg
# source_path /tmp/PetImages/Cat/cat.2127.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2127.jpg
# source_path /tmp/PetImages/Cat/cat.450.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.450.jpg
# source_path /tmp/PetImages/Cat/cat.535.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.535.jpg
# source_path /tmp/PetImages/Cat/cat.2119.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2119.jpg
# source_path /tmp/PetImages/Cat/cat.2128.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2128.jpg
# source_path /tmp/PetImages/Cat/cat.30.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.30.jpg
# source_path /tmp/PetImages/Cat/cat.2024.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2024.jpg
# source_path /tmp/PetImages/Cat/cat.974.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.974.jpg
# source_path /tmp/PetImages/Cat/cat.261.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.261.jpg
# source_path /tmp/PetImages/Cat/cat.440.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.440.jpg
# source_path /tmp/PetImages/Cat/cat.2243.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2243.jpg
# source_path /tmp/PetImages/Cat/cat.2210.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2210.jpg
# source_path /tmp/PetImages/Cat/cat.582.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.582.jpg
# source_path /tmp/PetImages/Cat/cat.2414.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2414.jpg
# source_path /tmp/PetImages/Cat/cat.263.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.263.jpg
# source_path /tmp/PetImages/Cat/cat.2309.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2309.jpg
# source_path /tmp/PetImages/Cat/cat.2224.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2224.jpg
# source_path /tmp/PetImages/Cat/cat.492.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.492.jpg
# source_path /tmp/PetImages/Cat/cat.978.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.978.jpg
# source_path /tmp/PetImages/Cat/cat.2437.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2437.jpg
# source_path /tmp/PetImages/Cat/cat.713.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.713.jpg
# source_path /tmp/PetImages/Cat/cat.623.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.623.jpg
# source_path /tmp/PetImages/Cat/cat.577.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.577.jpg
# source_path /tmp/PetImages/Cat/cat.2063.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2063.jpg
# source_path /tmp/PetImages/Cat/cat.792.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.792.jpg
# source_path /tmp/PetImages/Cat/cat.833.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.833.jpg
# source_path /tmp/PetImages/Cat/cat.317.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.317.jpg
# source_path /tmp/PetImages/Cat/cat.1.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.1.jpg
# source_path /tmp/PetImages/Cat/cat.983.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.983.jpg
# source_path /tmp/PetImages/Cat/cat.725.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.725.jpg
# source_path /tmp/PetImages/Cat/cat.794.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.794.jpg
# source_path /tmp/PetImages/Cat/cat.233.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.233.jpg
# source_path /tmp/PetImages/Cat/cat.837.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.837.jpg
# source_path /tmp/PetImages/Cat/cat.153.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.153.jpg
# source_path /tmp/PetImages/Cat/cat.98.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.98.jpg
# source_path /tmp/PetImages/Cat/cat.2040.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2040.jpg
# source_path /tmp/PetImages/Cat/cat.818.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.818.jpg
# source_path /tmp/PetImages/Cat/cat.676.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.676.jpg
# source_path /tmp/PetImages/Cat/cat.398.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.398.jpg
# source_path /tmp/PetImages/Cat/cat.2103.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2103.jpg
# source_path /tmp/PetImages/Cat/cat.2055.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2055.jpg
# source_path /tmp/PetImages/Cat/cat.2336.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2336.jpg
# source_path /tmp/PetImages/Cat/cat.619.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.619.jpg
# source_path /tmp/PetImages/Cat/cat.715.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.715.jpg
# source_path /tmp/PetImages/Cat/cat.2351.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2351.jpg
# source_path /tmp/PetImages/Cat/cat.482.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.482.jpg
# source_path /tmp/PetImages/Cat/cat.2467.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2467.jpg
# source_path /tmp/PetImages/Cat/cat.2143.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2143.jpg
# source_path /tmp/PetImages/Cat/cat.2164.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2164.jpg
# source_path /tmp/PetImages/Cat/cat.874.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.874.jpg
# source_path /tmp/PetImages/Cat/cat.531.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.531.jpg
# source_path /tmp/PetImages/Cat/cat.2410.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2410.jpg
# source_path /tmp/PetImages/Cat/cat.712.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.712.jpg
# source_path /tmp/PetImages/Cat/cat.554.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.554.jpg
# source_path /tmp/PetImages/Cat/cat.240.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.240.jpg
# source_path /tmp/PetImages/Cat/cat.2193.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2193.jpg
# source_path /tmp/PetImages/Cat/cat.2110.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2110.jpg
# source_path /tmp/PetImages/Cat/cat.854.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.854.jpg
# source_path /tmp/PetImages/Cat/cat.48.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.48.jpg
# source_path /tmp/PetImages/Cat/cat.2457.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2457.jpg
# source_path /tmp/PetImages/Cat/cat.363.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.363.jpg
# source_path /tmp/PetImages/Cat/cat.2449.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2449.jpg
# source_path /tmp/PetImages/Cat/cat.2404.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2404.jpg
# source_path /tmp/PetImages/Cat/cat.702.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.702.jpg
# source_path /tmp/PetImages/Cat/cat.364.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.364.jpg
# source_path /tmp/PetImages/Cat/cat.736.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.736.jpg
# source_path /tmp/PetImages/Cat/cat.906.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.906.jpg
# source_path /tmp/PetImages/Cat/cat.358.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.358.jpg
# source_path /tmp/PetImages/Cat/cat.2071.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2071.jpg
# source_path /tmp/PetImages/Cat/cat.126.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.126.jpg
# source_path /tmp/PetImages/Cat/cat.139.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.139.jpg
# source_path /tmp/PetImages/Cat/cat.198.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.198.jpg
# source_path /tmp/PetImages/Cat/cat.2288.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2288.jpg
# source_path /tmp/PetImages/Cat/cat.2059.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2059.jpg
# source_path /tmp/PetImages/Cat/cat.2438.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2438.jpg
# source_path /tmp/PetImages/Cat/cat.49.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.49.jpg
# source_path /tmp/PetImages/Cat/cat.181.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.181.jpg
# source_path /tmp/PetImages/Cat/cat.763.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.763.jpg
# source_path /tmp/PetImages/Cat/cat.500.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.500.jpg
# source_path /tmp/PetImages/Cat/cat.2140.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2140.jpg
# source_path /tmp/PetImages/Cat/cat.2408.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2408.jpg
# source_path /tmp/PetImages/Cat/cat.2479.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2479.jpg
# source_path /tmp/PetImages/Cat/cat.865.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.865.jpg
# source_path /tmp/PetImages/Cat/cat.805.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.805.jpg
# source_path /tmp/PetImages/Cat/cat.2017.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2017.jpg
# source_path /tmp/PetImages/Cat/cat.2360.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2360.jpg
# source_path /tmp/PetImages/Cat/cat.389.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.389.jpg
# source_path /tmp/PetImages/Cat/cat.2074.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2074.jpg
# source_path /tmp/PetImages/Cat/cat.2022.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2022.jpg
# source_path /tmp/PetImages/Cat/cat.2169.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2169.jpg
# source_path /tmp/PetImages/Cat/cat.17.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.17.jpg
# source_path /tmp/PetImages/Cat/cat.2326.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2326.jpg
# source_path /tmp/PetImages/Cat/cat.603.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.603.jpg
# source_path /tmp/PetImages/Cat/cat.2183.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2183.jpg
# source_path /tmp/PetImages/Cat/cat.720.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.720.jpg
# source_path /tmp/PetImages/Cat/cat.2225.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2225.jpg
# source_path /tmp/PetImages/Cat/cat.2078.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2078.jpg
# source_path /tmp/PetImages/Cat/cat.566.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.566.jpg
# source_path /tmp/PetImages/Cat/cat.897.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.897.jpg
# source_path /tmp/PetImages/Cat/cat.514.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.514.jpg
# source_path /tmp/PetImages/Cat/cat.954.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.954.jpg
# source_path /tmp/PetImages/Cat/cat.2452.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2452.jpg
# source_path /tmp/PetImages/Cat/cat.723.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.723.jpg
# source_path /tmp/PetImages/Cat/cat.2431.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2431.jpg
# source_path /tmp/PetImages/Cat/cat.213.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.213.jpg
# source_path /tmp/PetImages/Cat/cat.2051.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2051.jpg
# source_path /tmp/PetImages/Cat/cat.933.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.933.jpg
# source_path /tmp/PetImages/Cat/cat.273.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.273.jpg
# source_path /tmp/PetImages/Cat/cat.23.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.23.jpg
# source_path /tmp/PetImages/Cat/cat.350.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.350.jpg
# source_path /tmp/PetImages/Cat/cat.2323.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2323.jpg
# source_path /tmp/PetImages/Cat/cat.629.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.629.jpg
# source_path /tmp/PetImages/Cat/cat.813.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.813.jpg
# source_path /tmp/PetImages/Cat/cat.2321.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2321.jpg
# source_path /tmp/PetImages/Cat/cat.661.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.661.jpg
# source_path /tmp/PetImages/Cat/cat.101.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.101.jpg
# source_path /tmp/PetImages/Cat/cat.755.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.755.jpg
# source_path /tmp/PetImages/Cat/cat.605.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.605.jpg
# source_path /tmp/PetImages/Cat/cat.326.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.326.jpg
# source_path /tmp/PetImages/Cat/cat.825.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.825.jpg
# source_path /tmp/PetImages/Cat/cat.2205.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2205.jpg
# source_path /tmp/PetImages/Cat/cat.613.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.613.jpg
# source_path /tmp/PetImages/Cat/cat.2396.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2396.jpg
# source_path /tmp/PetImages/Cat/cat.2418.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2418.jpg
# source_path /tmp/PetImages/Cat/cat.957.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.957.jpg
# source_path /tmp/PetImages/Cat/cat.2064.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2064.jpg
# source_path /tmp/PetImages/Cat/cat.2154.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2154.jpg
# source_path /tmp/PetImages/Cat/cat.561.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.561.jpg
# source_path /tmp/PetImages/Cat/cat.626.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.626.jpg
# source_path /tmp/PetImages/Cat/cat.674.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.674.jpg
# source_path /tmp/PetImages/Cat/cat.2124.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2124.jpg
# source_path /tmp/PetImages/Cat/cat.2354.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2354.jpg
# source_path /tmp/PetImages/Cat/cat.2056.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2056.jpg
# source_path /tmp/PetImages/Cat/cat.653.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.653.jpg
# source_path /tmp/PetImages/Cat/cat.946.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.946.jpg
# source_path /tmp/PetImages/Cat/cat.2334.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2334.jpg
# source_path /tmp/PetImages/Cat/cat.2482.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2482.jpg
# source_path /tmp/PetImages/Cat/cat.765.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.765.jpg
# source_path /tmp/PetImages/Cat/cat.523.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.523.jpg
# source_path /tmp/PetImages/Cat/cat.414.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.414.jpg
# source_path /tmp/PetImages/Cat/cat.336.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.336.jpg
# source_path /tmp/PetImages/Cat/cat.2062.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2062.jpg
# source_path /tmp/PetImages/Cat/cat.693.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.693.jpg
# source_path /tmp/PetImages/Cat/cat.408.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.408.jpg
# source_path /tmp/PetImages/Cat/cat.883.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.883.jpg
# source_path /tmp/PetImages/Cat/cat.2204.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2204.jpg
# source_path /tmp/PetImages/Cat/cat.600.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.600.jpg
# source_path /tmp/PetImages/Cat/cat.33.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.33.jpg
# source_path /tmp/PetImages/Cat/cat.541.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.541.jpg
# source_path /tmp/PetImages/Cat/cat.2315.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2315.jpg
# source_path /tmp/PetImages/Cat/cat.556.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.556.jpg
# source_path /tmp/PetImages/Cat/cat.9.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.9.jpg
# source_path /tmp/PetImages/Cat/cat.286.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.286.jpg
# source_path /tmp/PetImages/Cat/cat.958.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.958.jpg
# source_path /tmp/PetImages/Cat/cat.40.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.40.jpg
# source_path /tmp/PetImages/Cat/cat.247.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.247.jpg
# source_path /tmp/PetImages/Cat/cat.657.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.657.jpg
# source_path /tmp/PetImages/Cat/cat.964.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.964.jpg
# source_path /tmp/PetImages/Cat/cat.2177.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2177.jpg
# source_path /tmp/PetImages/Cat/cat.606.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.606.jpg
# source_path /tmp/PetImages/Cat/cat.2337.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2337.jpg
# source_path /tmp/PetImages/Cat/cat.499.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.499.jpg
# source_path /tmp/PetImages/Cat/cat.734.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.734.jpg
# source_path /tmp/PetImages/Cat/cat.907.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.907.jpg
# source_path /tmp/PetImages/Cat/cat.2045.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2045.jpg
# source_path /tmp/PetImages/Cat/cat.202.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.202.jpg
# source_path /tmp/PetImages/Cat/cat.133.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.133.jpg
# source_path /tmp/PetImages/Cat/cat.2057.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2057.jpg
# source_path /tmp/PetImages/Cat/cat.2382.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2382.jpg
# source_path /tmp/PetImages/Cat/cat.617.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.617.jpg
# source_path /tmp/PetImages/Cat/cat.5.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.5.jpg
# source_path /tmp/PetImages/Cat/cat.2407.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2407.jpg
# source_path /tmp/PetImages/Cat/cat.374.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.374.jpg
# source_path /tmp/PetImages/Cat/cat.2307.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.2307.jpg
# source_path /tmp/PetImages/Cat/cat.668.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.668.jpg
# source_path /tmp/PetImages/Cat/cat.550.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.550.jpg
# source_path /tmp/PetImages/Cat/cat.576.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.576.jpg
# source_path /tmp/PetImages/Cat/cat.746.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.746.jpg
# source_path /tmp/PetImages/Cat/cat.121.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.121.jpg
# source_path /tmp/PetImages/Cat/cat.772.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.772.jpg
# source_path /tmp/PetImages/Cat/cat.762.jpg
# destination_path /tmp/cats-v-dogs/training/cats/cat.762.jpg
# source_path /tmp/PetImages/Cat/cat.2480.jpg
# ...
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2423.jpg
# source_path /tmp/PetImages/Dog/dog.2466.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2466.jpg
# source_path /tmp/PetImages/Dog/dog.376.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.376.jpg
# source_path /tmp/PetImages/Dog/dog.2068.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2068.jpg
# source_path /tmp/PetImages/Dog/dog.519.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.519.jpg
# source_path /tmp/PetImages/Dog/dog.221.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.221.jpg
# source_path /tmp/PetImages/Dog/dog.126.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.126.jpg
# source_path /tmp/PetImages/Dog/dog.684.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.684.jpg
# source_path /tmp/PetImages/Dog/dog.2074.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2074.jpg
# source_path /tmp/PetImages/Dog/dog.505.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.505.jpg
# source_path /tmp/PetImages/Dog/dog.982.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.982.jpg
# source_path /tmp/PetImages/Dog/dog.36.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.36.jpg
# source_path /tmp/PetImages/Dog/dog.243.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.243.jpg
# source_path /tmp/PetImages/Dog/dog.188.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.188.jpg
# source_path /tmp/PetImages/Dog/dog.737.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.737.jpg
# source_path /tmp/PetImages/Dog/dog.2285.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2285.jpg
# source_path /tmp/PetImages/Dog/dog.899.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.899.jpg
# source_path /tmp/PetImages/Dog/dog.821.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.821.jpg
# source_path /tmp/PetImages/Dog/dog.2450.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2450.jpg
# source_path /tmp/PetImages/Dog/dog.164.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.164.jpg
# source_path /tmp/PetImages/Dog/dog.484.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.484.jpg
# source_path /tmp/PetImages/Dog/dog.931.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.931.jpg
# source_path /tmp/PetImages/Dog/dog.2268.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2268.jpg
# source_path /tmp/PetImages/Dog/dog.964.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.964.jpg
# source_path /tmp/PetImages/Dog/dog.829.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.829.jpg
# source_path /tmp/PetImages/Dog/dog.683.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.683.jpg
# source_path /tmp/PetImages/Dog/dog.2290.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2290.jpg
# source_path /tmp/PetImages/Dog/dog.2338.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2338.jpg
# source_path /tmp/PetImages/Dog/dog.638.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.638.jpg
# source_path /tmp/PetImages/Dog/dog.2215.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2215.jpg
# source_path /tmp/PetImages/Dog/dog.369.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.369.jpg
# source_path /tmp/PetImages/Dog/dog.403.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.403.jpg
# source_path /tmp/PetImages/Dog/dog.620.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.620.jpg
# source_path /tmp/PetImages/Dog/dog.17.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.17.jpg
# source_path /tmp/PetImages/Dog/dog.647.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.647.jpg
# source_path /tmp/PetImages/Dog/dog.610.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.610.jpg
# source_path /tmp/PetImages/Dog/dog.2021.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2021.jpg
# source_path /tmp/PetImages/Dog/dog.2391.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2391.jpg
# source_path /tmp/PetImages/Dog/dog.593.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.593.jpg
# source_path /tmp/PetImages/Dog/dog.2451.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2451.jpg
# source_path /tmp/PetImages/Dog/dog.2473.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2473.jpg
# source_path /tmp/PetImages/Dog/dog.851.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.851.jpg
# source_path /tmp/PetImages/Dog/dog.814.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.814.jpg
# source_path /tmp/PetImages/Dog/dog.645.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.645.jpg
# source_path /tmp/PetImages/Dog/dog.2134.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2134.jpg
# source_path /tmp/PetImages/Dog/dog.2030.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2030.jpg
# source_path /tmp/PetImages/Dog/dog.2192.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2192.jpg
# source_path /tmp/PetImages/Dog/dog.82.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.82.jpg
# source_path /tmp/PetImages/Dog/dog.937.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.937.jpg
# source_path /tmp/PetImages/Dog/dog.456.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.456.jpg
# source_path /tmp/PetImages/Dog/dog.2319.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2319.jpg
# source_path /tmp/PetImages/Dog/dog.825.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.825.jpg
# source_path /tmp/PetImages/Dog/dog.669.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.669.jpg
# source_path /tmp/PetImages/Dog/dog.2121.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2121.jpg
# source_path /tmp/PetImages/Dog/dog.946.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.946.jpg
# source_path /tmp/PetImages/Dog/dog.392.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.392.jpg
# source_path /tmp/PetImages/Dog/dog.68.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.68.jpg
# source_path /tmp/PetImages/Dog/dog.2498.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2498.jpg
# source_path /tmp/PetImages/Dog/dog.24.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.24.jpg
# source_path /tmp/PetImages/Dog/dog.507.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.507.jpg
# source_path /tmp/PetImages/Dog/dog.2117.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2117.jpg
# source_path /tmp/PetImages/Dog/dog.2143.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2143.jpg
# source_path /tmp/PetImages/Dog/dog.2003.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2003.jpg
# source_path /tmp/PetImages/Dog/dog.941.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.941.jpg
# source_path /tmp/PetImages/Dog/dog.275.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.275.jpg
# source_path /tmp/PetImages/Dog/dog.923.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.923.jpg
# source_path /tmp/PetImages/Dog/dog.2047.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2047.jpg
# source_path /tmp/PetImages/Dog/dog.2310.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2310.jpg
# source_path /tmp/PetImages/Dog/dog.4.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.4.jpg
# source_path /tmp/PetImages/Dog/dog.364.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.364.jpg
# source_path /tmp/PetImages/Dog/dog.852.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.852.jpg
# source_path /tmp/PetImages/Dog/dog.159.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.159.jpg
# source_path /tmp/PetImages/Dog/dog.2224.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2224.jpg
# source_path /tmp/PetImages/Dog/dog.980.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.980.jpg
# source_path /tmp/PetImages/Dog/dog.918.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.918.jpg
# source_path /tmp/PetImages/Dog/dog.2312.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2312.jpg
# source_path /tmp/PetImages/Dog/dog.2187.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2187.jpg
# source_path /tmp/PetImages/Dog/dog.877.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.877.jpg
# source_path /tmp/PetImages/Dog/dog.660.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.660.jpg
# source_path /tmp/PetImages/Dog/dog.654.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.654.jpg
# source_path /tmp/PetImages/Dog/dog.796.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.796.jpg
# source_path /tmp/PetImages/Dog/dog.573.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.573.jpg
# source_path /tmp/PetImages/Dog/dog.106.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.106.jpg
# source_path /tmp/PetImages/Dog/dog.2424.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2424.jpg
# source_path /tmp/PetImages/Dog/dog.992.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.992.jpg
# source_path /tmp/PetImages/Dog/dog.2145.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2145.jpg
# source_path /tmp/PetImages/Dog/dog.2373.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2373.jpg
# source_path /tmp/PetImages/Dog/dog.20.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.20.jpg
# source_path /tmp/PetImages/Dog/dog.440.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.440.jpg
# source_path /tmp/PetImages/Dog/dog.165.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.165.jpg
# source_path /tmp/PetImages/Dog/dog.397.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.397.jpg
# source_path /tmp/PetImages/Dog/dog.955.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.955.jpg
# source_path /tmp/PetImages/Dog/dog.389.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.389.jpg
# source_path /tmp/PetImages/Dog/dog.703.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.703.jpg
# source_path /tmp/PetImages/Dog/dog.2108.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2108.jpg
# source_path /tmp/PetImages/Dog/dog.264.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.264.jpg
# source_path /tmp/PetImages/Dog/dog.355.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.355.jpg
# source_path /tmp/PetImages/Dog/dog.461.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.461.jpg
# source_path /tmp/PetImages/Dog/dog.351.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.351.jpg
# source_path /tmp/PetImages/Dog/dog.234.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.234.jpg
# source_path /tmp/PetImages/Dog/dog.652.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.652.jpg
# source_path /tmp/PetImages/Dog/dog.711.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.711.jpg
# source_path /tmp/PetImages/Dog/dog.2045.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2045.jpg
# source_path /tmp/PetImages/Dog/dog.783.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.783.jpg
# source_path /tmp/PetImages/Dog/dog.2016.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2016.jpg
# source_path /tmp/PetImages/Dog/dog.893.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.893.jpg
# source_path /tmp/PetImages/Dog/dog.678.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.678.jpg
# source_path /tmp/PetImages/Dog/dog.781.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.781.jpg
# source_path /tmp/PetImages/Dog/dog.753.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.753.jpg
# source_path /tmp/PetImages/Dog/dog.372.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.372.jpg
# source_path /tmp/PetImages/Dog/dog.764.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.764.jpg
# source_path /tmp/PetImages/Dog/dog.2217.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2217.jpg
# source_path /tmp/PetImages/Dog/dog.600.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.600.jpg
# source_path /tmp/PetImages/Dog/dog.2353.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2353.jpg
# source_path /tmp/PetImages/Dog/dog.849.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.849.jpg
# source_path /tmp/PetImages/Dog/dog.2222.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2222.jpg
# source_path /tmp/PetImages/Dog/dog.2119.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2119.jpg
# source_path /tmp/PetImages/Dog/dog.613.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.613.jpg
# source_path /tmp/PetImages/Dog/dog.2359.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2359.jpg
# source_path /tmp/PetImages/Dog/dog.2316.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2316.jpg
# source_path /tmp/PetImages/Dog/dog.2447.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2447.jpg
# source_path /tmp/PetImages/Dog/dog.828.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.828.jpg
# source_path /tmp/PetImages/Dog/dog.2176.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2176.jpg
# source_path /tmp/PetImages/Dog/dog.161.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.161.jpg
# source_path /tmp/PetImages/Dog/dog.532.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.532.jpg
# source_path /tmp/PetImages/Dog/dog.901.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.901.jpg
# source_path /tmp/PetImages/Dog/dog.900.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.900.jpg
# source_path /tmp/PetImages/Dog/dog.2317.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2317.jpg
# source_path /tmp/PetImages/Dog/dog.309.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.309.jpg
# source_path /tmp/PetImages/Dog/dog.308.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.308.jpg
# source_path /tmp/PetImages/Dog/dog.874.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.874.jpg
# source_path /tmp/PetImages/Dog/dog.2160.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2160.jpg
# source_path /tmp/PetImages/Dog/dog.2128.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2128.jpg
# source_path /tmp/PetImages/Dog/dog.333.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.333.jpg
# source_path /tmp/PetImages/Dog/dog.247.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.247.jpg
# source_path /tmp/PetImages/Dog/dog.847.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.847.jpg
# source_path /tmp/PetImages/Dog/dog.2110.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2110.jpg
# source_path /tmp/PetImages/Dog/dog.830.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.830.jpg
# source_path /tmp/PetImages/Dog/dog.78.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.78.jpg
# source_path /tmp/PetImages/Dog/dog.58.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.58.jpg
# source_path /tmp/PetImages/Dog/dog.122.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.122.jpg
# source_path /tmp/PetImages/Dog/dog.2066.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2066.jpg
# source_path /tmp/PetImages/Dog/dog.46.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.46.jpg
# source_path /tmp/PetImages/Dog/dog.26.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.26.jpg
# source_path /tmp/PetImages/Dog/dog.217.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.217.jpg
# source_path /tmp/PetImages/Dog/dog.360.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.360.jpg
# source_path /tmp/PetImages/Dog/dog.112.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.112.jpg
# source_path /tmp/PetImages/Dog/dog.896.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.896.jpg
# source_path /tmp/PetImages/Dog/dog.225.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.225.jpg
# source_path /tmp/PetImages/Dog/dog.256.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.256.jpg
# source_path /tmp/PetImages/Dog/dog.2383.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2383.jpg
# source_path /tmp/PetImages/Dog/dog.2216.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2216.jpg
# source_path /tmp/PetImages/Dog/dog.2280.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.2280.jpg
# source_path /tmp/PetImages/Dog/dog.953.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.953.jpg
# source_path /tmp/PetImages/Dog/dog.148.jpg
# destination_path /tmp/cats-v-dogs/training/dogs/dog.148.jpg

# %%
print(len(os.listdir('/tmp/cats-v-dogs/training/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/training/dogs/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/dogs/')))

# Expected output:
# 1350
# 1350
# 150
# 150
# Out:
# 1350
# 1350
# 150
# 150

# %%
# DEFINE A KERAS MODEL TO CLASSIFY CATS V DOGS
# USE AT LEAST 3 CONVOLUTION LAYERS
model = tf.keras.models.Sequential([
# YOUR CODE HERE
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), 
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['acc'])

# %% [markdown]
# # NOTE:
#
# In the cell below you **MUST** use a batch size of 10 (`batch_size=10`) for the `train_generator` and the `validation_generator`. Using a batch size greater than 10 will exceed memory limits on the Coursera platform.

# %%
TRAINING_DIR = "/tmp/cats-v-dogs/training"#YOUR CODE HERE
train_datagen = ImageDataGenerator(rescale=1.0/255)#YOUR CODE HERE

# NOTE: YOU MUST USE A BATCH SIZE OF 10 (batch_size=10) FOR THE 
# TRAIN GENERATOR.
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    batch_size=10,
                                                    class_mode='binary',
                                                    target_size=(150, 150))#YOUR CODE HERE

VALIDATION_DIR = "/tmp/cats-v-dogs/testing"#YOUR CODE HERE
validation_datagen = ImageDataGenerator(rescale=1.0/255)#YOUR CODE HERE

# NOTE: YOU MUST USE A BACTH SIZE OF 10 (batch_size=10) FOR THE 
# VALIDATION GENERATOR.
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              batch_size=10,
                                                              class_mode='binary',
                                                              target_size=(150, 150))#YOUR CODE HERE



# Expected Output:
# Found 2700 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.
# Out:
# Found 2700 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %%
history = model.fit_generator(train_generator,
                              epochs=2,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/2
# 270/270 [==============================] - 36s 132ms/step - loss: 1.2502 - acc: 0.5689 - val_loss: 0.6389 - val_acc: 0.6000
# Epoch 2/2
# 270/270 [==============================] - 31s 113ms/step - loss: 0.6170 - acc: 0.6748 - val_loss: 0.6142 - val_acc: 0.6400

# %%
# PLOT LOSS AND ACCURACY
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['acc']
val_acc=history.history['val_acc']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")


plt.title('Training and validation loss')

# Desired output. Charts with training and validation metrics. No crash :)

# %% [markdown]
# # Submission Instructions

# %%
# Now click the 'Submit Assignment' button above.

# %% [markdown]
# # When you're done or would like to take a break, please run the two cells below to save your work and close the Notebook. This will free up resources for your fellow learners.

# %%
# %%javascript
# <!-- Save the notebook -->
# IPython.notebook.save_checkpoint();

# %%
# %%javascript
# IPython.notebook.session.delete();
# window.onbeforeunload = null
# setTimeout(function() { window.close(); }, 1000);
